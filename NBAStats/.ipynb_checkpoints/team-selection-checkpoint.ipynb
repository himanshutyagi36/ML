# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from itertools import permutations

# %%
## load data
players_df = pd.read_csv('data/player_data_cleaned.csv', header=0, index_col=0, sep=',')
players_df['decades'] = players_df['decades'].apply(lambda x: tuple(x.split('|')))
players_df['positions'] = players_df['positions'].apply(lambda x: tuple(x.split('|')))
players_df.head()
# Out:
#                 height  weight                      collage    born  \
# Player
# Freddie Lewis    188.0    88.0  Eastern Kentucky University  1921.0
# Bob Cousy*       185.0    79.0    College of the Holy Cross  1928.0
# Richie Guerin*   193.0    88.0                 Iona College  1932.0
# Jim Paxson       198.0    90.0         University of Dayton  1932.0
# Hot Rod          193.0    83.0                          NaN  1935.0
#
#                birth_city birth_state  decades positions   OWS   DWS  \
# Player
# Freddie Lewis    Brooklyn    New York      70s     (PG,)   0.4   0.2
# Bob Cousy*       New York    New York      70s     (PG,)   0.0   0.0
# Richie Guerin*   New York    New York      70s     (SG,)  -0.1   0.0
# Jim Paxson      Pennville     Indiana  80s|90s  (SG, PG)  38.7  16.0
# Hot Rod               NaN         NaN  80s|90s   (C, PF)  33.5  36.9
#
#                   ...          FG%       2P%       3P%       FT%        MPG  \
# Player            ...
# Freddie Lewis     ...     0.407035  0.407035  0.000000  0.805195  17.250000
# Bob Cousy*        ...     0.333333  0.333333  0.000000  1.000000   4.857143
# Richie Guerin*    ...     0.272727  0.272727  0.000000  1.000000   8.000000
# Jim Paxson        ...     0.496448  0.510195  0.225877  0.808320  26.728589
# Hot Rod           ...     0.480146  0.481075  0.105263  0.725792  29.680947
#
#                      TRG       APG        PPG      PFPG      WS48
# Player
# Freddie Lewis   1.468750  1.750000   7.000000  1.812500  0.043478
# Bob Cousy*      0.714286  1.428571   0.714286  1.571429  0.141176
# Richie Guerin*  0.250000  1.500000   0.875000  1.125000 -0.075000
# Jim Paxson      1.975875  2.866104  13.927624  1.827503  0.119144
# Hot Rod         6.762120  1.794814  11.030440  2.540023  0.128720
#
# [5 rows x 21 columns]
